# %% [markdown]
# <a href="https://colab.research.google.com/github/wallaceleonardo/bootcamp-IGTI-Desenvolvedor_Python/blob/main/Desafio_Modulo_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Desafio do Módulo 2 - Bootcamp Desenvolvedor Python**

# %%
# Importando as bibliotecas
import numpy as np
import pandas as pd

# %%
# Importando o dataset
df = pd.read_csv("https://pycourse.s3.amazonaws.com/bike-sharing.csv", parse_dates=['datetime'])

# %%
df.head()
# Out:
#     datetime  rec_id  season  year  ...  windspeed  casual  registered  total_count
# 0 2011-01-01       1       1     0  ...        0.0       3          13           16
# 1 2011-01-01       2       1     0  ...        0.0       8          32           40
# 2 2011-01-01       3       1     0  ...        0.0       5          27           32
# 3 2011-01-01       4       1     0  ...        0.0       3          10           13
# 4 2011-01-01       5       1     0  ...        0.0       0           1            1
#
# [5 rows x 17 columns]

# %%
df.tail()
# Out:
#         datetime  rec_id  season  ...  casual  registered  total_count
# 17374 2012-12-31   17375       1  ...      11         108          119
# 17375 2012-12-31   17376       1  ...       8          81           89
# 17376 2012-12-31   17377       1  ...       7          83           90
# 17377 2012-12-31   17378       1  ...      13          48           61
# 17378 2012-12-31   17379       1  ...      12          37           49
#
# [5 rows x 17 columns]

# %%
# Estatistícas do dataset
df.describe()
# Out:
#            rec_id        season  ...    registered   total_count
# count  17379.0000  17379.000000  ...  17379.000000  17379.000000
# mean    8690.0000      2.501640  ...    153.786869    189.463088
# std     5017.0295      1.106918  ...    151.357286    181.387599
# min        1.0000      1.000000  ...      0.000000      1.000000
# 25%     4345.5000      2.000000  ...     34.000000     40.000000
# 50%     8690.0000      3.000000  ...    115.000000    142.000000
# 75%    13034.5000      3.000000  ...    220.000000    281.000000
# max    17379.0000      4.000000  ...    886.000000    977.000000
#
# [8 rows x 16 columns]

# %%
# informações do dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   datetime           17379 non-null  datetime64[ns]
#  1   rec_id             17379 non-null  int64
#  2   season             17379 non-null  int64
#  3   year               17379 non-null  int64
#  4   month              17379 non-null  int64
#  5   hour               17379 non-null  int64
#  6   is_holiday         17379 non-null  int64
#  7   weekday            17379 non-null  int64
#  8   is_workingday      17379 non-null  int64
#  9   weather_condition  17379 non-null  int64
#  10  temp               17379 non-null  float64
#  11  atemp              17379 non-null  float64
#  12  humidity           17379 non-null  float64
#  13  windspeed          17379 non-null  float64
#  14  casual             17379 non-null  int64
#  15  registered         17379 non-null  int64
# ...

# %%
# a. Qual o tamanho desse dataset?
df.shape
# Out:
# (17379, 17)

# %%
# b. Qual a média da coluna windspeed?
df['windspeed'].mean()
# Out:
# 0.1900976063064631

# %%
# c. Qual a média da coluna temp?
df['temp'].mean()
# Out:
# 0.4969871684216586

# %%
# d. Quantos registros existem para o ano de 2011?
filtro = df['datetime'].dt.year == 2011
df.loc[filtro]
# Out:
#        datetime  rec_id  season  ...  casual  registered  total_count
# 0    2011-01-01       1       1  ...       3          13           16
# 1    2011-01-01       2       1  ...       8          32           40
# 2    2011-01-01       3       1  ...       5          27           32
# 3    2011-01-01       4       1  ...       3          10           13
# 4    2011-01-01       5       1  ...       0           1            1
# ...         ...     ...     ...  ...     ...         ...          ...
# 8640 2011-12-31    8641       1  ...      19          73           92
# 8641 2011-12-31    8642       1  ...       8          63           71
# 8642 2011-12-31    8643       1  ...       2          50           52
# 8643 2011-12-31    8644       1  ...       2          36           38
# 8644 2011-12-31    8645       1  ...       4          27           31
#
# [8645 rows x 17 columns]

# %%
# e. Quantos registros existem para o ano de 2012?
filtro = df['datetime'].dt.year == 2012
df.loc[filtro]
# Out:
#         datetime  rec_id  season  ...  casual  registered  total_count
# 8645  2012-01-01    8646       1  ...       5          43           48
# 8646  2012-01-01    8647       1  ...      15          78           93
# 8647  2012-01-01    8648       1  ...      16          59           75
# 8648  2012-01-01    8649       1  ...      11          41           52
# 8649  2012-01-01    8650       1  ...       0           8            8
# ...          ...     ...     ...  ...     ...         ...          ...
# 17374 2012-12-31   17375       1  ...      11         108          119
# 17375 2012-12-31   17376       1  ...       8          81           89
# 17376 2012-12-31   17377       1  ...       7          83           90
# 17377 2012-12-31   17378       1  ...      13          48           61
# 17378 2012-12-31   17379       1  ...      12          37           49
#
# [8734 rows x 17 columns]

# %%
# f. Quantas locações de bicicletas foram efetuadas em 2011?
df.groupby(df['datetime'].dt.year)['total_count'].sum()
# Out:
# datetime
# 2011    1243103
# 2012    2049576
# Name: total_count, dtype: int64

# %%
# g. Quantas locações de bicicletas foram efetuadas em 2012?
df.groupby(df['datetime'].dt.year)['total_count'].sum()
# Out:
# datetime
# 2011    1243103
# 2012    2049576
# Name: total_count, dtype: int64

# %%
# h. Qual estação do ano contém a maior média de locações de bicicletas?
filtro = df.groupby('season')['total_count'].mean().reset_index()
filtro[filtro['total_count'] == filtro['total_count'].max()]
# Out:
#    season  total_count
# 2       3   236.016237

# %%
# i. Qual estação do ano contém a menor média de locações de bicicletas?
filtro = df.groupby('season')['total_count'].mean().reset_index()
filtro[filtro['total_count'] == filtro['total_count'].min()]
# Out:
#    season  total_count
# 0       1   111.114569

# %%
# j. Qual horário do dia contém a maior média de locações de bicicletas?
filtro = df.groupby('hour')['total_count'].mean().reset_index()
filtro[filtro['total_count'] == filtro['total_count'].max()]
# Out:
#     hour  total_count
# 17    17   461.452055

# %%
# k. Qual horário do dia contém a menor média de locações de bicicletas?
filtro = df.groupby('hour')['total_count'].mean().reset_index()
filtro[filtro['total_count'] == filtro['total_count'].min()]
# Out:
#    hour  total_count
# 4     4     6.352941

# %%
# l. Que dia da semana contém a maior média de locações de bicicletas?
filtro = df.groupby('weekday')['total_count'].mean().reset_index()
filtro[filtro['total_count'] == filtro['total_count'].max()]
# Out:
#    weekday  total_count
# 4        4   196.436665

# %%
# m. Que dia da semana contém a menor média de locações de bicicletas?
filtro = df.groupby('weekday')['total_count'].mean().reset_index()
filtro[filtro['total_count'] == filtro['total_count'].min()]
# Out:
#    weekday  total_count
# 0        0   177.468825

# %%
# n. Às quartas-feiras (weekday = 3), qual o horário do dia contém a maior média de locações de bicicletas?
filtro = df[df['weekday'] == 3].groupby('hour')['total_count'].mean().reset_index()
filtro[filtro['total_count'] == filtro['total_count'].max()]
# Out:
#     hour  total_count
# 17    17   513.144231

# %%
# o. Aos sábados (weekday = 6), qual o horário do dia contém a maior média de locações de bicicletas?
filtro = df[df['weekday'] == 6].groupby('hour')['total_count'].mean().reset_index()
filtro[filtro['total_count'] == filtro['total_count'].max()]
# Out:
#     hour  total_count
# 13    13   385.371429
